# %%
# %run func_defs.ipynb

# %run NN_defs.ipynb

import time, os, random
seed = 42

start_new_nn = 1
ns = 300 ;
Lz=10 ; tf = 20; 
k1=1.0; k2= 2.0 
lr = .01
wd = .0001
epochs = 10000000
betas = (0.995, 0.999)
tol = 5e-08

out_file= f'./model/2layer_ns{ns}_tol{tol}_reg.pt'
dat_file = f'./data/2layer_interpol_ns{ns}.pt'
#dat_file = f'./data/2layer_k1{k1}_k2{k2}_ns{ns}.pt'

d_in= 4

# %%
# set a dictionary of parameters
params_def = {'d_in':4, 'd_out':1, 'layers':4, 'nodes':64,
    'tol':0.5e-6, 'epochs':1000000, 'seg_size':1000, 'epoch_0':0,
    'lr':0.005, 'eps':1e-10, 'betas':(0.995, 0.999), 'wd':1e-4,
    'L':10, 'N':100000, 'N_test':100000,
    'start_new_nn':1, 'dat_file':f'./data/tm_in.pt',
    'out_file':f'./data/tm_out.pt'} 
for name in params_def: # using existing unless not existent
    if name not in globals():
        globals()[name] = params_def[name]

sec_main = """
# Load the training data
trn_dat = torch.load(dat_file, weights_only=True)

device = torch.device('cuda')

stau = trn_dat['stau']
W = trn_dat['W']
kratio = trn_dat['kratio']
z_disv = trn_dat['zdis']



train = torch.stack([stau[:,0],stau[:,1], kratio, z_disv], dim=-1)

xtrain = train.to(torch.float64)
ytrain = W.to(torch.float64)

print(train.shape)
print(W.shape)
if start_new_nn == 1:
    model, optimizer = build_nn() # build a new model
    model = model.to(device)
    del start_new_nn
else:
    model, optimizer = rebuild_nn() # rebuild the model from saved data
    model = model.to(device)
    for state in optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.to(device)
print(f'neural network model is on {next(model.parameters()).device}')
print_params() # print parameters
#
trained_model = train_nn() # train the model
for key in trained_model: # unpack trained_model
    globals()[key] = trained_model[key]
# test_result = test_and_plotting() # test the model and plot results
# for key in test_result: # unpack test_result
   # globals()[key] = test_result[key]
#
print_params()
[print(msg) for msg in msg_train]
# [print(msg) for msg in msg_test
save_model_vars() # save the model and variables in a dictionary
"""

# %%
# run the code unless func_def_only ==1

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

exec(sec_main)
# Out:
# torch.Size([45000, 4])
# torch.Size([45000, 1])
# neural network model is on cuda:0
# Structure of neural network:  Net(
#   (layers): ModuleList(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1-3): 3 x Linear(in_features=64, out_features=64, bias=True)
#   )
#   (out): Linear(in_features=64, out_features=1, bias=True)
# )
# Optimizer:   AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.995, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-10
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 0.0001
# )
# parameters: d_in = 4, d_out = 1, layers = 4, nodes = 64
#     tol = 5.0000e-08, epochs = 10000000, seg_size = 1000, epoch_0 = 0
#     N_train = 100000, N_test = 100000
#     output file: ./model/2layer_ns300_tol5e-08_reg.pt
#
# i = 0, loss = 4.6872e-02 loss_curr_min = 4.6872e-02
# Elapsed time = 0.07s,  CA time = Fri Jul 24 17:12:07 2026
# i = 1000, loss = 4.3136e-02 loss_curr_min = 4.3131e-02
# Elapsed time = 11.04s,  CA time = Fri Jul 24 17:12:18 2026
# i = 2000, loss = 4.3133e-02 loss_curr_min = 4.3131e-02
# Elapsed time = 21.94s,  CA time = Fri Jul 24 17:12:28 2026
# i = 3000, loss = 4.3132e-02 loss_curr_min = 4.3131e-02
# Elapsed time = 32.84s,  CA time = Fri Jul 24 17:12:39 2026
# i = 4000, loss = 4.3132e-02 loss_curr_min = 4.3131e-02
# Elapsed time = 43.74s,  CA time = Fri Jul 24 17:12:50 2026
# i = 5000, loss = 4.3132e-02 loss_curr_min = 4.3131e-02
# Elapsed time = 55.21s,  CA time = Fri Jul 24 17:13:02 2026
# i = 6000, loss = 4.3131e-02 loss_curr_min = 4.3131e-02
# Elapsed time = 66.23s,  CA time = Fri Jul 24 17:13:13 2026
# i = 7000, loss = 1.3557e-04 loss_curr_min = 1.3557e-04
# Elapsed time = 77.13s,  CA time = Fri Jul 24 17:13:24 2026
# i = 8000, loss = 3.6244e-05 loss_curr_min = 3.6140e-05
# Elapsed time = 88.05s,  CA time = Fri Jul 24 17:13:35 2026
# i = 9000, loss = 2.4413e-05 loss_curr_min = 2.4413e-05
# Elapsed time = 99.07s,  CA time = Fri Jul 24 17:13:46 2026
# i = 10000, loss = 1.3711e-05 loss_curr_min = 1.3626e-05
# Elapsed time = 110.11s,  CA time = Fri Jul 24 17:13:57 2026
# i = 11000, loss = 9.0540e-06 loss_curr_min = 9.0415e-06
# Elapsed time = 121.15s,  CA time = Fri Jul 24 17:14:08 2026
# i = 12000, loss = 7.3398e-06 loss_curr_min = 7.2038e-06
# Elapsed time = 132.17s,  CA time = Fri Jul 24 17:14:19 2026
# i = 13000, loss = 6.3040e-06 loss_curr_min = 6.2704e-06
# Elapsed time = 143.21s,  CA time = Fri Jul 24 17:14:30 2026
# i = 14000, loss = 5.7898e-06 loss_curr_min = 5.5713e-06
# Elapsed time = 154.27s,  CA time = Fri Jul 24 17:14:41 2026
# i = 15000, loss = 5.0593e-06 loss_curr_min = 5.0512e-06
# Elapsed time = 165.31s,  CA time = Fri Jul 24 17:14:52 2026
# i = 16000, loss = 4.6851e-06 loss_curr_min = 4.4911e-06
# Elapsed time = 176.32s,  CA time = Fri Jul 24 17:15:03 2026
# i = 17000, loss = 3.9088e-06 loss_curr_min = 3.8744e-06
# Elapsed time = 187.28s,  CA time = Fri Jul 24 17:15:14 2026
# i = 18000, loss = 3.5881e-06 loss_curr_min = 3.3615e-06
# Elapsed time = 198.25s,  CA time = Fri Jul 24 17:15:25 2026
# i = 19000, loss = 3.1169e-06 loss_curr_min = 2.9373e-06
# Elapsed time = 209.25s,  CA time = Fri Jul 24 17:15:36 2026
# i = 20000, loss = 2.7570e-06 loss_curr_min = 2.5911e-06
# Elapsed time = 220.27s,  CA time = Fri Jul 24 17:15:47 2026
# i = 21000, loss = 2.4668e-06 loss_curr_min = 2.3026e-06
# Elapsed time = 231.28s,  CA time = Fri Jul 24 17:15:58 2026
# i = 22000, loss = 2.1012e-06 loss_curr_min = 2.0654e-06
# Elapsed time = 242.29s,  CA time = Fri Jul 24 17:16:09 2026
# i = 23000, loss = 1.8558e-06 loss_curr_min = 1.8558e-06
# Elapsed time = 253.30s,  CA time = Fri Jul 24 17:16:20 2026
# i = 24000, loss = 1.9135e-06 loss_curr_min = 1.7083e-06
# Elapsed time = 264.34s,  CA time = Fri Jul 24 17:16:31 2026
# i = 25000, loss = 1.8401e-06 loss_curr_min = 1.5946e-06
# Elapsed time = 275.39s,  CA time = Fri Jul 24 17:16:42 2026
# i = 26000, loss = 1.6713e-06 loss_curr_min = 1.4988e-06
# Elapsed time = 286.43s,  CA time = Fri Jul 24 17:16:53 2026
# i = 27000, loss = 1.4675e-06 loss_curr_min = 1.4270e-06
# Elapsed time = 297.50s,  CA time = Fri Jul 24 17:17:04 2026
# i = 28000, loss = 1.3980e-06 loss_curr_min = 1.3564e-06
# Elapsed time = 308.55s,  CA time = Fri Jul 24 17:17:15 2026
# i = 29000, loss = 1.4126e-06 loss_curr_min = 1.2884e-06
# Elapsed time = 319.51s,  CA time = Fri Jul 24 17:17:26 2026
# i = 30000, loss = 1.4438e-06 loss_curr_min = 1.2150e-06
# Elapsed time = 330.53s,  CA time = Fri Jul 24 17:17:37 2026
# i = 31000, loss = 1.2504e-06 loss_curr_min = 1.1452e-06
# Elapsed time = 341.59s,  CA time = Fri Jul 24 17:17:48 2026
# i = 32000, loss = 1.2757e-06 loss_curr_min = 1.0749e-06
# Elapsed time = 352.69s,  CA time = Fri Jul 24 17:17:59 2026
# i = 33000, loss = 1.1142e-06 loss_curr_min = 1.0055e-06
# Elapsed time = 363.81s,  CA time = Fri Jul 24 17:18:10 2026
# i = 34000, loss = 1.0993e-06 loss_curr_min = 9.3502e-07
# Elapsed time = 374.86s,  CA time = Fri Jul 24 17:18:21 2026
# i = 35000, loss = 1.1122e-06 loss_curr_min = 8.6386e-07
# Elapsed time = 385.85s,  CA time = Fri Jul 24 17:18:32 2026
# i = 36000, loss = 8.7619e-07 loss_curr_min = 7.9793e-07
# Elapsed time = 396.80s,  CA time = Fri Jul 24 17:18:43 2026
# i = 37000, loss = 8.4232e-07 loss_curr_min = 7.4263e-07
# Elapsed time = 407.75s,  CA time = Fri Jul 24 17:18:54 2026
# i = 38000, loss = 8.7314e-07 loss_curr_min = 6.9659e-07
# Elapsed time = 418.70s,  CA time = Fri Jul 24 17:19:05 2026
# i = 39000, loss = 7.2369e-07 loss_curr_min = 6.5357e-07
# Elapsed time = 429.67s,  CA time = Fri Jul 24 17:19:16 2026
# i = 40000, loss = 7.8694e-07 loss_curr_min = 6.1125e-07
# Elapsed time = 440.64s,  CA time = Fri Jul 24 17:19:27 2026
# i = 41000, loss = 6.4615e-07 loss_curr_min = 5.6500e-07
# Elapsed time = 451.67s,  CA time = Fri Jul 24 17:19:38 2026
# i = 42000, loss = 7.4552e-07 loss_curr_min = 5.1479e-07
# Elapsed time = 462.67s,  CA time = Fri Jul 24 17:19:49 2026
# i = 43000, loss = 4.7471e-07 loss_curr_min = 4.6479e-07
# Elapsed time = 473.66s,  CA time = Fri Jul 24 17:20:00 2026
# i = 44000, loss = 5.5674e-07 loss_curr_min = 4.2288e-07
# Elapsed time = 484.63s,  CA time = Fri Jul 24 17:20:11 2026
# i = 45000, loss = 6.3640e-07 loss_curr_min = 3.8958e-07
# Elapsed time = 495.66s,  CA time = Fri Jul 24 17:20:22 2026
# i = 46000, loss = 6.1929e-07 loss_curr_min = 3.6357e-07
# Elapsed time = 506.62s,  CA time = Fri Jul 24 17:20:33 2026
# i = 47000, loss = 5.9636e-07 loss_curr_min = 3.4339e-07
# Elapsed time = 517.67s,  CA time = Fri Jul 24 17:20:44 2026
# i = 48000, loss = 5.7242e-07 loss_curr_min = 3.2496e-07
# Elapsed time = 528.70s,  CA time = Fri Jul 24 17:20:55 2026
# i = 49000, loss = 5.5763e-07 loss_curr_min = 3.0968e-07
# Elapsed time = 539.73s,  CA time = Fri Jul 24 17:21:06 2026
# i = 50000, loss = 5.3298e-07 loss_curr_min = 2.9597e-07
# Elapsed time = 550.76s,  CA time = Fri Jul 24 17:21:17 2026
# i = 51000, loss = 4.8284e-07 loss_curr_min = 2.8453e-07
# Elapsed time = 561.78s,  CA time = Fri Jul 24 17:21:28 2026
# i = 52000, loss = 3.9233e-07 loss_curr_min = 2.7376e-07
# Elapsed time = 572.83s,  CA time = Fri Jul 24 17:21:39 2026
# i = 53000, loss = 2.9098e-07 loss_curr_min = 2.6375e-07
# Elapsed time = 583.88s,  CA time = Fri Jul 24 17:21:50 2026
# i = 54000, loss = 2.6149e-07 loss_curr_min = 2.5542e-07
# Elapsed time = 594.87s,  CA time = Fri Jul 24 17:22:01 2026
# i = 55000, loss = 3.5610e-07 loss_curr_min = 2.4766e-07
# Elapsed time = 605.85s,  CA time = Fri Jul 24 17:22:12 2026
# i = 56000, loss = 4.7618e-07 loss_curr_min = 2.4051e-07
# Elapsed time = 616.83s,  CA time = Fri Jul 24 17:22:23 2026
# i = 57000, loss = 4.5621e-07 loss_curr_min = 2.3360e-07
# Elapsed time = 627.79s,  CA time = Fri Jul 24 17:22:34 2026
# i = 58000, loss = 3.0945e-07 loss_curr_min = 2.2742e-07
# Elapsed time = 638.81s,  CA time = Fri Jul 24 17:22:45 2026
# i = 59000, loss = 2.2189e-07 loss_curr_min = 2.2189e-07
# Elapsed time = 649.83s,  CA time = Fri Jul 24 17:22:56 2026
# i = 60000, loss = 3.0299e-07 loss_curr_min = 2.1704e-07
# Elapsed time = 660.89s,  CA time = Fri Jul 24 17:23:07 2026
# i = 61000, loss = 4.3612e-07 loss_curr_min = 2.1257e-07
# Elapsed time = 671.94s,  CA time = Fri Jul 24 17:23:18 2026
# i = 62000, loss = 4.4194e-07 loss_curr_min = 2.0853e-07
# Elapsed time = 682.97s,  CA time = Fri Jul 24 17:23:29 2026
# i = 63000, loss = 3.1528e-07 loss_curr_min = 2.0489e-07
# Elapsed time = 694.01s,  CA time = Fri Jul 24 17:23:41 2026
# i = 64000, loss = 2.0680e-07 loss_curr_min = 2.0154e-07
# Elapsed time = 705.05s,  CA time = Fri Jul 24 17:23:52 2026
# i = 65000, loss = 2.4152e-07 loss_curr_min = 1.9845e-07
# Elapsed time = 716.07s,  CA time = Fri Jul 24 17:24:03 2026
# i = 66000, loss = 3.7349e-07 loss_curr_min = 1.9561e-07
# Elapsed time = 727.10s,  CA time = Fri Jul 24 17:24:14 2026
# i = 67000, loss = 4.4033e-07 loss_curr_min = 1.9274e-07
# Elapsed time = 738.13s,  CA time = Fri Jul 24 17:24:25 2026
# i = 68000, loss = 3.6342e-07 loss_curr_min = 1.9021e-07
# Elapsed time = 749.14s,  CA time = Fri Jul 24 17:24:36 2026
# i = 69000, loss = 2.2947e-07 loss_curr_min = 1.8791e-07
# Elapsed time = 760.13s,  CA time = Fri Jul 24 17:24:47 2026
# i = 70000, loss = 1.9100e-07 loss_curr_min = 1.8579e-07
# Elapsed time = 771.16s,  CA time = Fri Jul 24 17:24:58 2026
# i = 71000, loss = 2.9250e-07 loss_curr_min = 1.8373e-07
# Elapsed time = 782.18s,  CA time = Fri Jul 24 17:25:09 2026
# i = 72000, loss = 4.1097e-07 loss_curr_min = 1.8181e-07
# Elapsed time = 793.24s,  CA time = Fri Jul 24 17:25:20 2026
# i = 73000, loss = 4.0030e-07 loss_curr_min = 1.7985e-07
# Elapsed time = 804.30s,  CA time = Fri Jul 24 17:25:31 2026
# i = 74000, loss = 2.6923e-07 loss_curr_min = 1.7808e-07
# Elapsed time = 815.36s,  CA time = Fri Jul 24 17:25:42 2026
# i = 75000, loss = 1.7731e-07 loss_curr_min = 1.7647e-07
# Elapsed time = 826.36s,  CA time = Fri Jul 24 17:25:53 2026
# i = 76000, loss = 2.4080e-07 loss_curr_min = 1.7495e-07
# Elapsed time = 837.36s,  CA time = Fri Jul 24 17:26:04 2026
# i = 77000, loss = 3.7816e-07 loss_curr_min = 1.7346e-07
# Elapsed time = 848.32s,  CA time = Fri Jul 24 17:26:15 2026
# i = 78000, loss = 4.0498e-07 loss_curr_min = 1.7203e-07
# Elapsed time = 859.35s,  CA time = Fri Jul 24 17:26:26 2026
# i = 79000, loss = 2.8202e-07 loss_curr_min = 1.7071e-07
# Elapsed time = 870.37s,  CA time = Fri Jul 24 17:26:37 2026
# i = 80000, loss = 1.7294e-07 loss_curr_min = 1.6938e-07
# Elapsed time = 881.39s,  CA time = Fri Jul 24 17:26:48 2026
# i = 81000, loss = 2.2533e-07 loss_curr_min = 1.6812e-07
# Elapsed time = 892.42s,  CA time = Fri Jul 24 17:26:59 2026
# i = 82000, loss = 3.6677e-07 loss_curr_min = 1.6691e-07
# Elapsed time = 903.46s,  CA time = Fri Jul 24 17:27:10 2026
# i = 83000, loss = 3.9604e-07 loss_curr_min = 1.6574e-07
# Elapsed time = 914.47s,  CA time = Fri Jul 24 17:27:21 2026
# i = 84000, loss = 2.6965e-07 loss_curr_min = 1.6461e-07
# Elapsed time = 925.51s,  CA time = Fri Jul 24 17:27:32 2026
# i = 85000, loss = 1.6513e-07 loss_curr_min = 1.6351e-07
# Elapsed time = 936.54s,  CA time = Fri Jul 24 17:27:43 2026
# i = 86000, loss = 2.3083e-07 loss_curr_min = 1.6242e-07
# Elapsed time = 947.59s,  CA time = Fri Jul 24 17:27:54 2026
# i = 87000, loss = 3.7124e-07 loss_curr_min = 1.6138e-07
# Elapsed time = 958.61s,  CA time = Fri Jul 24 17:28:05 2026
# i = 88000, loss = 3.7840e-07 loss_curr_min = 1.6039e-07
# Elapsed time = 969.61s,  CA time = Fri Jul 24 17:28:16 2026
# i = 89000, loss = 2.4057e-07 loss_curr_min = 1.5937e-07
# Elapsed time = 980.60s,  CA time = Fri Jul 24 17:28:27 2026
# i = 90000, loss = 1.5857e-07 loss_curr_min = 1.5853e-07
# Elapsed time = 991.59s,  CA time = Fri Jul 24 17:28:38 2026
# i = 91000, loss = 2.5197e-07 loss_curr_min = 1.5757e-07
# Elapsed time = 1002.63s,  CA time = Fri Jul 24 17:28:49 2026
# i = 92000, loss = 3.8026e-07 loss_curr_min = 1.5664e-07
# Elapsed time = 1013.68s,  CA time = Fri Jul 24 17:29:00 2026
# i = 93000, loss = 3.5276e-07 loss_curr_min = 1.5575e-07
# Elapsed time = 1024.76s,  CA time = Fri Jul 24 17:29:11 2026
# i = 94000, loss = 2.1043e-07 loss_curr_min = 1.5486e-07
# Elapsed time = 1035.81s,  CA time = Fri Jul 24 17:29:22 2026
# i = 95000, loss = 1.5833e-07 loss_curr_min = 1.5399e-07
# Elapsed time = 1046.86s,  CA time = Fri Jul 24 17:29:33 2026
# i = 96000, loss = 2.7085e-07 loss_curr_min = 1.5315e-07
# Elapsed time = 1057.89s,  CA time = Fri Jul 24 17:29:44 2026
# i = 97000, loss = 3.8187e-07 loss_curr_min = 1.5230e-07
# Elapsed time = 1068.87s,  CA time = Fri Jul 24 17:29:55 2026
# i = 98000, loss = 3.2832e-07 loss_curr_min = 1.5150e-07
# Elapsed time = 1079.82s,  CA time = Fri Jul 24 17:30:06 2026
# i = 99000, loss = 1.8643e-07 loss_curr_min = 1.5070e-07
# Elapsed time = 1090.86s,  CA time = Fri Jul 24 17:30:17 2026
# i = 100000, loss = 1.6555e-07 loss_curr_min = 1.4986e-07
# Elapsed time = 1101.92s,  CA time = Fri Jul 24 17:30:28 2026
# i = 101000, loss = 3.0226e-07 loss_curr_min = 1.4913e-07
# Elapsed time = 1112.97s,  CA time = Fri Jul 24 17:30:39 2026
# i = 102000, loss = 3.7793e-07 loss_curr_min = 1.4838e-07
# Elapsed time = 1123.99s,  CA time = Fri Jul 24 17:30:51 2026
# i = 103000, loss = 2.5951e-07 loss_curr_min = 1.4754e-07
# Elapsed time = 1135.03s,  CA time = Fri Jul 24 17:31:02 2026
# i = 104000, loss = 1.4703e-07 loss_curr_min = 1.4676e-07
# Elapsed time = 1146.07s,  CA time = Fri Jul 24 17:31:13 2026
# i = 105000, loss = 2.3864e-07 loss_curr_min = 1.4605e-07
# Elapsed time = 1157.10s,  CA time = Fri Jul 24 17:31:24 2026
# i = 106000, loss = 3.6617e-07 loss_curr_min = 1.4531e-07
# Elapsed time = 1168.13s,  CA time = Fri Jul 24 17:31:35 2026
# i = 107000, loss = 3.2792e-07 loss_curr_min = 1.4457e-07
# Elapsed time = 1179.17s,  CA time = Fri Jul 24 17:31:46 2026
# i = 108000, loss = 1.8919e-07 loss_curr_min = 1.4383e-07
# Elapsed time = 1190.21s,  CA time = Fri Jul 24 17:31:57 2026
# i = 109000, loss = 1.5131e-07 loss_curr_min = 1.4310e-07
# Elapsed time = 1201.23s,  CA time = Fri Jul 24 17:32:08 2026
# i = 110000, loss = 2.7205e-07 loss_curr_min = 1.4238e-07
# Elapsed time = 1212.26s,  CA time = Fri Jul 24 17:32:19 2026
# i = 111000, loss = 3.6859e-07 loss_curr_min = 1.4169e-07
# Elapsed time = 1223.29s,  CA time = Fri Jul 24 17:32:30 2026
# i = 112000, loss = 2.8692e-07 loss_curr_min = 1.4099e-07
# Elapsed time = 1234.28s,  CA time = Fri Jul 24 17:32:41 2026
# i = 113000, loss = 1.5312e-07 loss_curr_min = 1.4034e-07
# Elapsed time = 1245.30s,  CA time = Fri Jul 24 17:32:52 2026
# i = 114000, loss = 1.8647e-07 loss_curr_min = 1.3964e-07
# Elapsed time = 1256.35s,  CA time = Fri Jul 24 17:33:03 2026
# i = 115000, loss = 3.3571e-07 loss_curr_min = 1.3895e-07
# Elapsed time = 1267.38s,  CA time = Fri Jul 24 17:33:14 2026
# i = 116000, loss = 3.2947e-07 loss_curr_min = 1.3831e-07
# Elapsed time = 1278.44s,  CA time = Fri Jul 24 17:33:25 2026
# i = 117000, loss = 1.7151e-07 loss_curr_min = 1.3761e-07
# Elapsed time = 1289.55s,  CA time = Fri Jul 24 17:33:36 2026
# i = 118000, loss = 1.7204e-07 loss_curr_min = 1.3698e-07
# Elapsed time = 1300.62s,  CA time = Fri Jul 24 17:33:47 2026
# i = 119000, loss = 3.3703e-07 loss_curr_min = 1.3625e-07
# Elapsed time = 1311.74s,  CA time = Fri Jul 24 17:33:58 2026
# i = 120000, loss = 2.9687e-07 loss_curr_min = 1.3564e-07
# Elapsed time = 1322.86s,  CA time = Fri Jul 24 17:34:09 2026
# i = 121000, loss = 1.3870e-07 loss_curr_min = 1.3498e-07
# Elapsed time = 1334.00s,  CA time = Fri Jul 24 17:34:21 2026
# i = 122000, loss = 2.4636e-07 loss_curr_min = 1.3433e-07
# Elapsed time = 1345.12s,  CA time = Fri Jul 24 17:34:32 2026
# i = 123000, loss = 3.4712e-07 loss_curr_min = 1.3369e-07
# Elapsed time = 1356.25s,  CA time = Fri Jul 24 17:34:43 2026
# i = 124000, loss = 1.7866e-07 loss_curr_min = 1.3306e-07
# Elapsed time = 1367.38s,  CA time = Fri Jul 24 17:34:54 2026
# i = 125000, loss = 1.7429e-07 loss_curr_min = 1.3243e-07
# Elapsed time = 1378.50s,  CA time = Fri Jul 24 17:35:05 2026
# i = 126000, loss = 3.3981e-07 loss_curr_min = 1.3181e-07
# Elapsed time = 1389.60s,  CA time = Fri Jul 24 17:35:16 2026
# i = 127000, loss = 2.6611e-07 loss_curr_min = 1.3122e-07
# Elapsed time = 1400.72s,  CA time = Fri Jul 24 17:35:27 2026
# i = 128000, loss = 1.3176e-07 loss_curr_min = 1.3055e-07
# Elapsed time = 1411.83s,  CA time = Fri Jul 24 17:35:38 2026
# i = 129000, loss = 2.2606e-07 loss_curr_min = 1.2999e-07
# Elapsed time = 1422.91s,  CA time = Fri Jul 24 17:35:49 2026
# i = 130000, loss = 3.4406e-07 loss_curr_min = 1.2935e-07
# Elapsed time = 1434.05s,  CA time = Fri Jul 24 17:36:01 2026
# i = 131000, loss = 2.5839e-07 loss_curr_min = 1.2877e-07
# Elapsed time = 1445.19s,  CA time = Fri Jul 24 17:36:12 2026
# i = 132000, loss = 1.3440e-07 loss_curr_min = 1.2815e-07
# Elapsed time = 1456.38s,  CA time = Fri Jul 24 17:36:23 2026
# i = 133000, loss = 1.8278e-07 loss_curr_min = 1.2754e-07
# Elapsed time = 1467.46s,  CA time = Fri Jul 24 17:36:34 2026
# i = 134000, loss = 3.1586e-07 loss_curr_min = 1.2693e-07
# Elapsed time = 1478.57s,  CA time = Fri Jul 24 17:36:45 2026
# i = 135000, loss = 3.1666e-07 loss_curr_min = 1.2641e-07
# Elapsed time = 1489.65s,  CA time = Fri Jul 24 17:36:56 2026
