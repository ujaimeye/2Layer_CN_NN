# %%
# %run func_defs.ipynb

# %run NN_defs.ipynb

import time, os, random
seed = 42

start_new_nn = 1
nz = 80 ;
Lz=10 ; tf = 2; 
k1=1.0; k2= 2.0 
lr = .01
wd = .0001
epochs = 10000000
betas = (0.995, 0.999)
tol = 5e-08
#nodes = 32
out_file= f'./model/2layer_nz{nz}_tf{tf}.pt'
dat_file = f'./data/2layer_k1{k1}_k2{k2}_nz{nz}.pt'
d_in= 4

# %%
# set a dictionary of parameters
params_def = {'d_in':4, 'd_out':1, 'layers':4, 'nodes':64,
    'tol':0.5e-6, 'epochs':1000000, 'seg_size':1000, 'epoch_0':0,
    'lr':0.005, 'eps':1e-10, 'betas':(0.995, 0.999), 'wd':1e-4,
    'L':10, 'N':100000, 'N_test':100000,
    'start_new_nn':1, 'dat_file':f'./data/tm_in.pt',
    'out_file':f'./data/tm_out.pt'} 
for name in params_def: # using existing unless not existent
    if name not in globals():
        globals()[name] = params_def[name]

sec_main = """
# Load the training data
trn_dat = torch.load(dat_file, weights_only=True)

device = torch.device('cuda')

stau = trn_dat['stau']
W = trn_dat['W']
kratio = trn_dat['kratio']
z_disv = trn_dat['zdis']


train = torch.stack([stau[:,0],stau[:,1], kratio, z_disv], dim=-1)

xtrain = train.to(torch.float64)
ytrain = W.to(torch.float64)

if start_new_nn == 1:
    model, optimizer = build_nn() # build a new model
    model = model.to(device)
    del start_new_nn
else:
    model, optimizer = rebuild_nn() # rebuild the model from saved data
    model = model.to(device)
    for state in optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.to(device)
print(f'neural network model is on {next(model.parameters()).device}')
print_params() # print parameters
#
trained_model = train_nn() # train the model
for key in trained_model: # unpack trained_model
    globals()[key] = trained_model[key]
# test_result = test_and_plotting() # test the model and plot results
# for key in test_result: # unpack test_result
   # globals()[key] = test_result[key]
#
print_params()
[print(msg) for msg in msg_train]
# [print(msg) for msg in msg_test
save_model_vars() # save the model and variables in a dictionary
"""

# %%
# run the code unless func_def_only ==1

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

exec(sec_main)
# Out:
# torch.Size([8100, 2])
# torch.Size([8100, 1])
# neural network model is on cuda:0
# Structure of neural network:  Net(
#   (layers): ModuleList(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1-3): 3 x Linear(in_features=64, out_features=64, bias=True)
#   )
#   (out): Linear(in_features=64, out_features=1, bias=True)
# )
# Optimizer:   AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.995, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-10
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 0.0001
# )
# parameters: d_in = 4, d_out = 1, layers = 4, nodes = 64
#     tol = 5.0000e-08, epochs = 10000000, seg_size = 1000, epoch_0 = 0
#     N_train = 100000, N_test = 100000
#     output file: ./model/2layer_nz80_tf2.pt
#
# i = 0, loss = 1.0549e-01 loss_curr_min = 1.0549e-01
# Elapsed time = 0.00s,  CA time = Tue May 12 17:52:02 2026
# i = 1000, loss = 2.8096e-02 loss_curr_min = 2.8049e-02
# Elapsed time = 3.64s,  CA time = Tue May 12 17:52:06 2026
# i = 2000, loss = 1.6824e-04 loss_curr_min = 1.5514e-04
# Elapsed time = 7.20s,  CA time = Tue May 12 17:52:09 2026
# i = 3000, loss = 2.5130e-05 loss_curr_min = 2.3347e-05
# Elapsed time = 10.77s,  CA time = Tue May 12 17:52:13 2026
# i = 4000, loss = 5.2567e-06 loss_curr_min = 5.2567e-06
# Elapsed time = 14.33s,  CA time = Tue May 12 17:52:16 2026
# i = 5000, loss = 4.7333e-06 loss_curr_min = 4.7333e-06
# Elapsed time = 17.91s,  CA time = Tue May 12 17:52:20 2026
# i = 6000, loss = 4.6612e-06 loss_curr_min = 4.5955e-06
# Elapsed time = 21.48s,  CA time = Tue May 12 17:52:23 2026
# i = 7000, loss = 4.6319e-06 loss_curr_min = 4.4856e-06
# Elapsed time = 25.04s,  CA time = Tue May 12 17:52:27 2026
# i = 8000, loss = 4.3559e-06 loss_curr_min = 4.3292e-06
# Elapsed time = 28.62s,  CA time = Tue May 12 17:52:31 2026
# i = 9000, loss = 4.3070e-06 loss_curr_min = 4.1160e-06
# Elapsed time = 32.20s,  CA time = Tue May 12 17:52:34 2026
# i = 10000, loss = 3.8951e-06 loss_curr_min = 3.8810e-06
# Elapsed time = 35.77s,  CA time = Tue May 12 17:52:38 2026
# i = 11000, loss = 3.9031e-06 loss_curr_min = 3.6292e-06
# Elapsed time = 39.34s,  CA time = Tue May 12 17:52:41 2026
# i = 12000, loss = 3.4001e-06 loss_curr_min = 3.3746e-06
# Elapsed time = 42.90s,  CA time = Tue May 12 17:52:45 2026
# i = 13000, loss = 3.1183e-06 loss_curr_min = 3.1161e-06
# Elapsed time = 46.46s,  CA time = Tue May 12 17:52:48 2026
# i = 14000, loss = 3.0899e-06 loss_curr_min = 2.8591e-06
# Elapsed time = 50.03s,  CA time = Tue May 12 17:52:52 2026
# i = 15000, loss = 2.9931e-06 loss_curr_min = 2.5997e-06
# Elapsed time = 53.59s,  CA time = Tue May 12 17:52:56 2026
# i = 16000, loss = 2.4633e-06 loss_curr_min = 2.3146e-06
# Elapsed time = 57.16s,  CA time = Tue May 12 17:52:59 2026
# i = 17000, loss = 2.3583e-06 loss_curr_min = 2.0111e-06
# Elapsed time = 60.72s,  CA time = Tue May 12 17:53:03 2026
# i = 18000, loss = 1.8641e-06 loss_curr_min = 1.7534e-06
# Elapsed time = 64.28s,  CA time = Tue May 12 17:53:06 2026
# i = 19000, loss = 1.7463e-06 loss_curr_min = 1.5429e-06
# Elapsed time = 67.84s,  CA time = Tue May 12 17:53:10 2026
# i = 20000, loss = 1.8143e-06 loss_curr_min = 1.4113e-06
# Elapsed time = 71.39s,  CA time = Tue May 12 17:53:13 2026
# i = 21000, loss = 1.4257e-06 loss_curr_min = 1.3403e-06
# Elapsed time = 74.95s,  CA time = Tue May 12 17:53:17 2026
# i = 22000, loss = 1.4273e-06 loss_curr_min = 1.2913e-06
# Elapsed time = 78.54s,  CA time = Tue May 12 17:53:20 2026
# i = 23000, loss = 1.3882e-06 loss_curr_min = 1.2552e-06
# Elapsed time = 82.13s,  CA time = Tue May 12 17:53:24 2026
# i = 24000, loss = 1.5672e-06 loss_curr_min = 1.2259e-06
# Elapsed time = 85.72s,  CA time = Tue May 12 17:53:28 2026
# i = 25000, loss = 1.5251e-06 loss_curr_min = 1.2013e-06
# Elapsed time = 89.29s,  CA time = Tue May 12 17:53:31 2026
# i = 26000, loss = 1.4733e-06 loss_curr_min = 1.1788e-06
# Elapsed time = 92.85s,  CA time = Tue May 12 17:53:35 2026
# i = 27000, loss = 1.4647e-06 loss_curr_min = 1.1598e-06
# Elapsed time = 96.41s,  CA time = Tue May 12 17:53:38 2026
# i = 28000, loss = 1.4438e-06 loss_curr_min = 1.1418e-06
# Elapsed time = 99.98s,  CA time = Tue May 12 17:53:42 2026
# i = 29000, loss = 1.2435e-06 loss_curr_min = 1.1249e-06
# Elapsed time = 103.53s,  CA time = Tue May 12 17:53:45 2026
# i = 30000, loss = 1.2168e-06 loss_curr_min = 1.1094e-06
# Elapsed time = 107.10s,  CA time = Tue May 12 17:53:49 2026
# i = 31000, loss = 1.1626e-06 loss_curr_min = 1.0951e-06
# Elapsed time = 110.66s,  CA time = Tue May 12 17:53:53 2026
# i = 32000, loss = 1.1775e-06 loss_curr_min = 1.0801e-06
# Elapsed time = 114.22s,  CA time = Tue May 12 17:53:56 2026
# i = 33000, loss = 1.0973e-06 loss_curr_min = 1.0669e-06
# Elapsed time = 117.79s,  CA time = Tue May 12 17:54:00 2026
# i = 34000, loss = 1.1038e-06 loss_curr_min = 1.0541e-06
# Elapsed time = 121.35s,  CA time = Tue May 12 17:54:03 2026
# i = 35000, loss = 1.0800e-06 loss_curr_min = 1.0408e-06
# Elapsed time = 124.92s,  CA time = Tue May 12 17:54:07 2026
# i = 36000, loss = 1.2764e-06 loss_curr_min = 1.0281e-06
# Elapsed time = 128.48s,  CA time = Tue May 12 17:54:10 2026
# i = 37000, loss = 1.0161e-06 loss_curr_min = 1.0140e-06
# Elapsed time = 132.05s,  CA time = Tue May 12 17:54:14 2026
# i = 38000, loss = 1.1973e-06 loss_curr_min = 9.9873e-07
# Elapsed time = 135.61s,  CA time = Tue May 12 17:54:18 2026
# i = 39000, loss = 1.1846e-06 loss_curr_min = 9.8261e-07
# Elapsed time = 139.18s,  CA time = Tue May 12 17:54:21 2026
# i = 40000, loss = 9.7487e-07 loss_curr_min = 9.6390e-07
# Elapsed time = 142.75s,  CA time = Tue May 12 17:54:25 2026
# i = 41000, loss = 1.1149e-06 loss_curr_min = 9.4194e-07
# Elapsed time = 146.31s,  CA time = Tue May 12 17:54:28 2026
# i = 42000, loss = 1.0474e-06 loss_curr_min = 9.1565e-07
# Elapsed time = 149.87s,  CA time = Tue May 12 17:54:32 2026
# i = 43000, loss = 9.0581e-07 loss_curr_min = 8.8233e-07
# Elapsed time = 153.44s,  CA time = Tue May 12 17:54:35 2026
# i = 44000, loss = 8.6505e-07 loss_curr_min = 8.4284e-07
# Elapsed time = 156.99s,  CA time = Tue May 12 17:54:39 2026
# i = 45000, loss = 9.1229e-07 loss_curr_min = 7.9825e-07
# Elapsed time = 160.56s,  CA time = Tue May 12 17:54:42 2026
# i = 46000, loss = 7.8380e-07 loss_curr_min = 7.5298e-07
# Elapsed time = 164.12s,  CA time = Tue May 12 17:54:46 2026
# i = 47000, loss = 8.0361e-07 loss_curr_min = 7.1270e-07
# Elapsed time = 167.69s,  CA time = Tue May 12 17:54:50 2026
# i = 48000, loss = 7.2201e-07 loss_curr_min = 6.8109e-07
# Elapsed time = 171.26s,  CA time = Tue May 12 17:54:53 2026
# i = 49000, loss = 8.1630e-07 loss_curr_min = 6.5404e-07
# Elapsed time = 174.82s,  CA time = Tue May 12 17:54:57 2026
# i = 50000, loss = 6.5451e-07 loss_curr_min = 6.3416e-07
# Elapsed time = 178.39s,  CA time = Tue May 12 17:55:00 2026
# i = 51000, loss = 7.6198e-07 loss_curr_min = 6.1660e-07
# Elapsed time = 181.96s,  CA time = Tue May 12 17:55:04 2026
# i = 52000, loss = 7.7005e-07 loss_curr_min = 6.0295e-07
# Elapsed time = 185.52s,  CA time = Tue May 12 17:55:07 2026
# i = 53000, loss = 7.3201e-07 loss_curr_min = 5.9071e-07
# Elapsed time = 189.09s,  CA time = Tue May 12 17:55:11 2026
# i = 54000, loss = 6.2997e-07 loss_curr_min = 5.7948e-07
# Elapsed time = 192.65s,  CA time = Tue May 12 17:55:15 2026
# i = 55000, loss = 5.7059e-07 loss_curr_min = 5.6697e-07
# Elapsed time = 196.21s,  CA time = Tue May 12 17:55:18 2026
# i = 56000, loss = 6.5327e-07 loss_curr_min = 5.5113e-07
# Elapsed time = 199.77s,  CA time = Tue May 12 17:55:22 2026
# i = 57000, loss = 6.9747e-07 loss_curr_min = 5.3429e-07
# Elapsed time = 203.33s,  CA time = Tue May 12 17:55:25 2026
# i = 58000, loss = 5.3912e-07 loss_curr_min = 5.2240e-07
# Elapsed time = 206.91s,  CA time = Tue May 12 17:55:29 2026
# i = 59000, loss = 6.2410e-07 loss_curr_min = 5.1352e-07
# Elapsed time = 210.47s,  CA time = Tue May 12 17:55:32 2026
# i = 60000, loss = 6.7595e-07 loss_curr_min = 5.0531e-07
# Elapsed time = 214.04s,  CA time = Tue May 12 17:55:36 2026
# i = 61000, loss = 6.0167e-07 loss_curr_min = 4.9754e-07
# Elapsed time = 217.62s,  CA time = Tue May 12 17:55:40 2026
# i = 62000, loss = 5.0137e-07 loss_curr_min = 4.8993e-07
# Elapsed time = 221.19s,  CA time = Tue May 12 17:55:43 2026
# i = 63000, loss = 5.0849e-07 loss_curr_min = 4.8249e-07
# Elapsed time = 224.76s,  CA time = Tue May 12 17:55:47 2026
# i = 64000, loss = 6.2861e-07 loss_curr_min = 4.7499e-07
# Elapsed time = 228.33s,  CA time = Tue May 12 17:55:50 2026
# i = 65000, loss = 5.2677e-07 loss_curr_min = 4.6728e-07
# Elapsed time = 231.91s,  CA time = Tue May 12 17:55:54 2026
# i = 66000, loss = 5.7461e-07 loss_curr_min = 4.5918e-07
# Elapsed time = 235.46s,  CA time = Tue May 12 17:55:57 2026
# i = 67000, loss = 5.3817e-07 loss_curr_min = 4.5183e-07
# Elapsed time = 239.03s,  CA time = Tue May 12 17:56:01 2026
# i = 68000, loss = 4.4464e-07 loss_curr_min = 4.4464e-07
# Elapsed time = 242.58s,  CA time = Tue May 12 17:56:05 2026
# i = 69000, loss = 4.3843e-07 loss_curr_min = 4.3843e-07
# Elapsed time = 246.15s,  CA time = Tue May 12 17:56:08 2026
# i = 70000, loss = 5.1030e-07 loss_curr_min = 4.3213e-07
# Elapsed time = 249.71s,  CA time = Tue May 12 17:56:12 2026
# i = 71000, loss = 5.6238e-07 loss_curr_min = 4.2624e-07
# Elapsed time = 253.27s,  CA time = Tue May 12 17:56:15 2026
# i = 72000, loss = 4.6122e-07 loss_curr_min = 4.2008e-07
# Elapsed time = 256.84s,  CA time = Tue May 12 17:56:19 2026
# i = 73000, loss = 4.6908e-07 loss_curr_min = 4.1380e-07
# Elapsed time = 260.40s,  CA time = Tue May 12 17:56:22 2026
# i = 74000, loss = 5.6365e-07 loss_curr_min = 4.0916e-07
# Elapsed time = 263.97s,  CA time = Tue May 12 17:56:26 2026
# i = 75000, loss = 5.5189e-07 loss_curr_min = 4.0296e-07
# Elapsed time = 267.54s,  CA time = Tue May 12 17:56:29 2026
# i = 76000, loss = 5.4682e-07 loss_curr_min = 3.9802e-07
# Elapsed time = 271.10s,  CA time = Tue May 12 17:56:33 2026
# i = 77000, loss = 4.9165e-07 loss_curr_min = 3.8912e-07
# Elapsed time = 274.67s,  CA time = Tue May 12 17:56:37 2026
# i = 78000, loss = 3.8488e-07 loss_curr_min = 3.8282e-07
# Elapsed time = 278.23s,  CA time = Tue May 12 17:56:40 2026
# i = 79000, loss = 5.1791e-07 loss_curr_min = 3.7554e-07
# Elapsed time = 281.79s,  CA time = Tue May 12 17:56:44 2026
# i = 80000, loss = 3.7571e-07 loss_curr_min = 3.6722e-07
# Elapsed time = 285.36s,  CA time = Tue May 12 17:56:47 2026
# i = 81000, loss = 4.9830e-07 loss_curr_min = 3.5863e-07
# Elapsed time = 288.92s,  CA time = Tue May 12 17:56:51 2026
# i = 82000, loss = 3.5954e-07 loss_curr_min = 3.4768e-07
# Elapsed time = 292.49s,  CA time = Tue May 12 17:56:54 2026
# i = 83000, loss = 4.0213e-07 loss_curr_min = 3.3591e-07
# Elapsed time = 296.05s,  CA time = Tue May 12 17:56:58 2026
# i = 84000, loss = 4.4526e-07 loss_curr_min = 3.2091e-07
# Elapsed time = 299.62s,  CA time = Tue May 12 17:57:02 2026
# i = 85000, loss = 3.0605e-07 loss_curr_min = 3.0520e-07
# Elapsed time = 303.19s,  CA time = Tue May 12 17:57:05 2026
# i = 86000, loss = 4.1608e-07 loss_curr_min = 2.8738e-07
# Elapsed time = 306.75s,  CA time = Tue May 12 17:57:09 2026
# i = 87000, loss = 3.2662e-07 loss_curr_min = 2.7252e-07
# Elapsed time = 310.32s,  CA time = Tue May 12 17:57:12 2026
# i = 88000, loss = 3.0027e-07 loss_curr_min = 2.5778e-07
# Elapsed time = 313.89s,  CA time = Tue May 12 17:57:16 2026
# i = 89000, loss = 3.7048e-07 loss_curr_min = 2.4790e-07
# Elapsed time = 317.45s,  CA time = Tue May 12 17:57:19 2026
# i = 90000, loss = 2.3822e-07 loss_curr_min = 2.3790e-07
# Elapsed time = 321.01s,  CA time = Tue May 12 17:57:23 2026
# i = 91000, loss = 2.3931e-07 loss_curr_min = 2.3007e-07
# Elapsed time = 324.57s,  CA time = Tue May 12 17:57:26 2026
# i = 92000, loss = 2.2958e-07 loss_curr_min = 2.2339e-07
# Elapsed time = 328.14s,  CA time = Tue May 12 17:57:30 2026
# i = 93000, loss = 2.9862e-07 loss_curr_min = 2.1672e-07
# Elapsed time = 331.71s,  CA time = Tue May 12 17:57:34 2026
# i = 94000, loss = 3.3264e-07 loss_curr_min = 2.1104e-07
# Elapsed time = 335.28s,  CA time = Tue May 12 17:57:37 2026
# i = 95000, loss = 3.3217e-07 loss_curr_min = 2.0554e-07
# Elapsed time = 338.84s,  CA time = Tue May 12 17:57:41 2026
# i = 96000, loss = 3.0829e-07 loss_curr_min = 2.0035e-07
# Elapsed time = 342.40s,  CA time = Tue May 12 17:57:44 2026
# i = 97000, loss = 2.7424e-07 loss_curr_min = 1.9527e-07
# Elapsed time = 345.97s,  CA time = Tue May 12 17:57:48 2026
# i = 98000, loss = 2.4513e-07 loss_curr_min = 1.9061e-07
# Elapsed time = 349.54s,  CA time = Tue May 12 17:57:51 2026
# i = 99000, loss = 2.1131e-07 loss_curr_min = 1.8560e-07
# Elapsed time = 353.11s,  CA time = Tue May 12 17:57:55 2026
# i = 100000, loss = 1.8697e-07 loss_curr_min = 1.8083e-07
# Elapsed time = 356.67s,  CA time = Tue May 12 17:57:59 2026
# i = 101000, loss = 2.5839e-07 loss_curr_min = 1.7597e-07
# Elapsed time = 360.23s,  CA time = Tue May 12 17:58:02 2026
# i = 102000, loss = 2.9778e-07 loss_curr_min = 1.7166e-07
# Elapsed time = 363.80s,  CA time = Tue May 12 17:58:06 2026
# i = 103000, loss = 2.2824e-07 loss_curr_min = 1.6769e-07
# Elapsed time = 367.37s,  CA time = Tue May 12 17:58:09 2026
# i = 104000, loss = 1.6410e-07 loss_curr_min = 1.6373e-07
# Elapsed time = 370.93s,  CA time = Tue May 12 17:58:13 2026
# i = 105000, loss = 2.2731e-07 loss_curr_min = 1.6017e-07
# Elapsed time = 374.49s,  CA time = Tue May 12 17:58:16 2026
# i = 106000, loss = 2.6549e-07 loss_curr_min = 1.5684e-07
# Elapsed time = 378.05s,  CA time = Tue May 12 17:58:20 2026
# i = 107000, loss = 2.5721e-07 loss_curr_min = 1.5358e-07
# Elapsed time = 381.61s,  CA time = Tue May 12 17:58:24 2026
# i = 108000, loss = 2.2373e-07 loss_curr_min = 1.5061e-07
# Elapsed time = 385.18s,  CA time = Tue May 12 17:58:27 2026
# i = 109000, loss = 1.9907e-07 loss_curr_min = 1.4763e-07
# Elapsed time = 388.74s,  CA time = Tue May 12 17:58:31 2026
# i = 110000, loss = 2.6093e-07 loss_curr_min = 1.4506e-07
# Elapsed time = 392.30s,  CA time = Tue May 12 17:58:34 2026
# i = 111000, loss = 1.9291e-07 loss_curr_min = 1.4266e-07
# Elapsed time = 395.86s,  CA time = Tue May 12 17:58:38 2026
# i = 112000, loss = 2.5834e-07 loss_curr_min = 1.4067e-07
# Elapsed time = 399.42s,  CA time = Tue May 12 17:58:41 2026
# i = 113000, loss = 2.3210e-07 loss_curr_min = 1.3844e-07
# Elapsed time = 402.99s,  CA time = Tue May 12 17:58:45 2026
# i = 114000, loss = 1.3865e-07 loss_curr_min = 1.3683e-07
# Elapsed time = 406.56s,  CA time = Tue May 12 17:58:48 2026
# i = 115000, loss = 2.2492e-07 loss_curr_min = 1.3532e-07
# Elapsed time = 410.12s,  CA time = Tue May 12 17:58:52 2026
# i = 116000, loss = 2.3042e-07 loss_curr_min = 1.3387e-07
# Elapsed time = 413.69s,  CA time = Tue May 12 17:58:56 2026
# i = 117000, loss = 2.1209e-07 loss_curr_min = 1.3277e-07
# Elapsed time = 417.26s,  CA time = Tue May 12 17:58:59 2026
# i = 118000, loss = 1.9965e-07 loss_curr_min = 1.3156e-07
# Elapsed time = 420.82s,  CA time = Tue May 12 17:59:03 2026
# i = 119000, loss = 2.1229e-07 loss_curr_min = 1.3035e-07
# Elapsed time = 424.39s,  CA time = Tue May 12 17:59:06 2026
# i = 120000, loss = 1.6233e-07 loss_curr_min = 1.2945e-07
# Elapsed time = 427.96s,  CA time = Tue May 12 17:59:10 2026
# i = 121000, loss = 1.3513e-07 loss_curr_min = 1.2840e-07
# Elapsed time = 431.53s,  CA time = Tue May 12 17:59:13 2026
# i = 122000, loss = 1.4443e-07 loss_curr_min = 1.2758e-07
# Elapsed time = 435.09s,  CA time = Tue May 12 17:59:17 2026
# i = 123000, loss = 1.6142e-07 loss_curr_min = 1.2664e-07
# Elapsed time = 438.66s,  CA time = Tue May 12 17:59:21 2026
# i = 124000, loss = 1.3357e-07 loss_curr_min = 1.2590e-07
# Elapsed time = 442.22s,  CA time = Tue May 12 17:59:24 2026
# i = 125000, loss = 2.4921e-07 loss_curr_min = 1.2507e-07
# Elapsed time = 445.78s,  CA time = Tue May 12 17:59:28 2026
# i = 126000, loss = 1.3150e-07 loss_curr_min = 1.2425e-07
# Elapsed time = 449.36s,  CA time = Tue May 12 17:59:31 2026
# i = 127000, loss = 2.2327e-07 loss_curr_min = 1.2338e-07
# Elapsed time = 452.94s,  CA time = Tue May 12 17:59:35 2026
# i = 128000, loss = 1.5397e-07 loss_curr_min = 1.2249e-07
# Elapsed time = 456.54s,  CA time = Tue May 12 17:59:38 2026
# i = 129000, loss = 2.3978e-07 loss_curr_min = 1.2178e-07
# Elapsed time = 460.12s,  CA time = Tue May 12 17:59:42 2026
# i = 130000, loss = 2.2195e-07 loss_curr_min = 1.2092e-07
# Elapsed time = 463.71s,  CA time = Tue May 12 17:59:46 2026
# i = 131000, loss = 2.0508e-07 loss_curr_min = 1.1990e-07
# Elapsed time = 467.30s,  CA time = Tue May 12 17:59:49 2026
# i = 132000, loss = 1.5742e-07 loss_curr_min = 1.1899e-07
# Elapsed time = 470.90s,  CA time = Tue May 12 17:59:53 2026
# i = 133000, loss = 1.2092e-07 loss_curr_min = 1.1820e-07
# Elapsed time = 474.49s,  CA time = Tue May 12 17:59:56 2026
# i = 134000, loss = 1.1785e-07 loss_curr_min = 1.1720e-07
# Elapsed time = 478.08s,  CA time = Tue May 12 18:00:00 2026
# i = 135000, loss = 1.3052e-07 loss_curr_min = 1.1618e-07
# Elapsed time = 481.67s,  CA time = Tue May 12 18:00:04 2026
# i = 136000, loss = 2.1418e-07 loss_curr_min = 1.1511e-07
# Elapsed time = 485.26s,  CA time = Tue May 12 18:00:07 2026
# i = 137000, loss = 2.1204e-07 loss_curr_min = 1.1418e-07
# Elapsed time = 488.85s,  CA time = Tue May 12 18:00:11 2026
# i = 138000, loss = 1.9176e-07 loss_curr_min = 1.1315e-07
# Elapsed time = 492.43s,  CA time = Tue May 12 18:00:14 2026
# i = 139000, loss = 1.1405e-07 loss_curr_min = 1.1203e-07
# Elapsed time = 496.01s,  CA time = Tue May 12 18:00:18 2026
# i = 140000, loss = 1.7952e-07 loss_curr_min = 1.1119e-07
# Elapsed time = 499.61s,  CA time = Tue May 12 18:00:22 2026
# i = 141000, loss = 2.0882e-07 loss_curr_min = 1.0990e-07
# Elapsed time = 503.19s,  CA time = Tue May 12 18:00:25 2026
# i = 142000, loss = 1.5204e-07 loss_curr_min = 1.0877e-07
# Elapsed time = 506.79s,  CA time = Tue May 12 18:00:29 2026
# i = 143000, loss = 1.6392e-07 loss_curr_min = 1.0747e-07
# Elapsed time = 510.38s,  CA time = Tue May 12 18:00:32 2026
# i = 144000, loss = 2.0894e-07 loss_curr_min = 1.0627e-07
# Elapsed time = 513.96s,  CA time = Tue May 12 18:00:36 2026
# i = 145000, loss = 1.9512e-07 loss_curr_min = 1.0480e-07
# Elapsed time = 517.55s,  CA time = Tue May 12 18:00:39 2026
# i = 146000, loss = 1.9763e-07 loss_curr_min = 1.0334e-07
# Elapsed time = 521.13s,  CA time = Tue May 12 18:00:43 2026
# i = 147000, loss = 1.5105e-07 loss_curr_min = 1.0199e-07
# Elapsed time = 524.71s,  CA time = Tue May 12 18:00:47 2026
# i = 148000, loss = 2.1682e-07 loss_curr_min = 1.0067e-07
# Elapsed time = 528.29s,  CA time = Tue May 12 18:00:50 2026
# i = 149000, loss = 1.1590e-07 loss_curr_min = 9.9455e-08
# Elapsed time = 531.89s,  CA time = Tue May 12 18:00:54 2026
# i = 150000, loss = 9.9316e-08 loss_curr_min = 9.8487e-08
# Elapsed time = 535.48s,  CA time = Tue May 12 18:00:57 2026
# i = 151000, loss = 1.0210e-07 loss_curr_min = 9.7255e-08
# Elapsed time = 539.08s,  CA time = Tue May 12 18:01:01 2026
# i = 152000, loss = 1.7147e-07 loss_curr_min = 9.6377e-08
# Elapsed time = 542.66s,  CA time = Tue May 12 18:01:05 2026
# i = 153000, loss = 1.7122e-07 loss_curr_min = 9.5329e-08
# Elapsed time = 546.25s,  CA time = Tue May 12 18:01:08 2026
# i = 154000, loss = 1.6198e-07 loss_curr_min = 9.4266e-08
# Elapsed time = 549.83s,  CA time = Tue May 12 18:01:12 2026
# i = 155000, loss = 1.5005e-07 loss_curr_min = 9.3158e-08
# Elapsed time = 553.42s,  CA time = Tue May 12 18:01:15 2026
# i = 156000, loss = 1.1826e-07 loss_curr_min = 9.2183e-08
# Elapsed time = 557.00s,  CA time = Tue May 12 18:01:19 2026
# i = 157000, loss = 9.4958e-08 loss_curr_min = 9.1452e-08
# Elapsed time = 560.59s,  CA time = Tue May 12 18:01:23 2026
# i = 158000, loss = 9.1399e-08 loss_curr_min = 9.0701e-08
# Elapsed time = 564.19s,  CA time = Tue May 12 18:01:26 2026
# i = 159000, loss = 8.9723e-08 loss_curr_min = 8.9723e-08
# Elapsed time = 567.77s,  CA time = Tue May 12 18:01:30 2026
# i = 160000, loss = 1.1979e-07 loss_curr_min = 8.8917e-08
# Elapsed time = 571.36s,  CA time = Tue May 12 18:01:33 2026
# i = 161000, loss = 1.7309e-07 loss_curr_min = 8.8245e-08
# Elapsed time = 574.94s,  CA time = Tue May 12 18:01:37 2026
# i = 162000, loss = 9.4682e-08 loss_curr_min = 8.7275e-08
# Elapsed time = 578.53s,  CA time = Tue May 12 18:01:40 2026
# i = 163000, loss = 1.4353e-07 loss_curr_min = 8.6437e-08
# Elapsed time = 582.12s,  CA time = Tue May 12 18:01:44 2026
# i = 164000, loss = 1.3827e-07 loss_curr_min = 8.5565e-08
# Elapsed time = 585.70s,  CA time = Tue May 12 18:01:48 2026
# i = 165000, loss = 9.4748e-08 loss_curr_min = 8.4675e-08
# Elapsed time = 589.30s,  CA time = Tue May 12 18:01:51 2026
# i = 166000, loss = 1.6528e-07 loss_curr_min = 8.3839e-08
# Elapsed time = 592.89s,  CA time = Tue May 12 18:01:55 2026
# i = 167000, loss = 8.6516e-08 loss_curr_min = 8.3039e-08
# Elapsed time = 596.49s,  CA time = Tue May 12 18:01:58 2026
# i = 168000, loss = 1.4646e-07 loss_curr_min = 8.2274e-08
# Elapsed time = 600.08s,  CA time = Tue May 12 18:02:02 2026
# i = 169000, loss = 1.1268e-07 loss_curr_min = 8.1543e-08
# Elapsed time = 603.67s,  CA time = Tue May 12 18:02:06 2026
# i = 170000, loss = 1.1657e-07 loss_curr_min = 8.0714e-08
# Elapsed time = 607.26s,  CA time = Tue May 12 18:02:09 2026
# i = 171000, loss = 1.3311e-07 loss_curr_min = 7.9974e-08
# Elapsed time = 610.85s,  CA time = Tue May 12 18:02:13 2026
# i = 172000, loss = 9.8706e-08 loss_curr_min = 7.9293e-08
# Elapsed time = 614.44s,  CA time = Tue May 12 18:02:16 2026
# i = 173000, loss = 1.4266e-07 loss_curr_min = 7.8543e-08
# Elapsed time = 618.02s,  CA time = Tue May 12 18:02:20 2026
# i = 174000, loss = 8.9513e-08 loss_curr_min = 7.7811e-08
# Elapsed time = 621.61s,  CA time = Tue May 12 18:02:24 2026
# i = 175000, loss = 1.4316e-07 loss_curr_min = 7.7090e-08
# Elapsed time = 625.20s,  CA time = Tue May 12 18:02:27 2026
# i = 176000, loss = 9.2975e-08 loss_curr_min = 7.6363e-08
# Elapsed time = 628.79s,  CA time = Tue May 12 18:02:31 2026
# i = 177000, loss = 1.2149e-07 loss_curr_min = 7.5499e-08
# Elapsed time = 632.37s,  CA time = Tue May 12 18:02:34 2026
# i = 178000, loss = 1.1604e-07 loss_curr_min = 7.4789e-08
# Elapsed time = 635.97s,  CA time = Tue May 12 18:02:38 2026
# i = 179000, loss = 1.0366e-07 loss_curr_min = 7.4041e-08
# Elapsed time = 639.56s,  CA time = Tue May 12 18:02:41 2026
# i = 180000, loss = 1.1774e-07 loss_curr_min = 7.3286e-08
# Elapsed time = 643.15s,  CA time = Tue May 12 18:02:45 2026
# i = 181000, loss = 1.0654e-07 loss_curr_min = 7.2521e-08
# Elapsed time = 646.74s,  CA time = Tue May 12 18:02:49 2026
# i = 182000, loss = 1.0487e-07 loss_curr_min = 7.1758e-08
# Elapsed time = 650.32s,  CA time = Tue May 12 18:02:52 2026
# i = 183000, loss = 1.2014e-07 loss_curr_min = 7.1064e-08
# Elapsed time = 653.91s,  CA time = Tue May 12 18:02:56 2026
# i = 184000, loss = 8.4546e-08 loss_curr_min = 7.0354e-08
# Elapsed time = 657.50s,  CA time = Tue May 12 18:02:59 2026
# Structure of neural network:  Net(
#   (layers): ModuleList(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1-3): 3 x Linear(in_features=64, out_features=64, bias=True)
#   )
#   (out): Linear(in_features=64, out_features=1, bias=True)
# )
# Optimizer:   AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.995, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-10
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 0.0001
# )
# parameters: d_in = 4, d_out = 1, layers = 4, nodes = 64
#     tol = 5.0000e-08, epochs = 10000000, seg_size = 1000, epoch_0 = 0
#     N_train = 100000, N_test = 100000
#     output file: ./model/2layer_nz80_tf2.pt
#
# Training info: tol_actual = 5.0000e-08, epochs_actual = 184546
#     loss_train(MSE) = 6.9997e-08
#     Elapsed time = 659.46s,  CA time = Tue May 12 18:03:01 2026
# dict_keys(['seed', 'nz', 'Lz', 'tf', 'k1', 'k2', 'lr', 'wd', 'epochs', 'tol', 'd_in', 'd_out', 'layers', 'nodes', 'seg_size', 'epoch_0', 'eps', 'L', 'N', 'N_test', 'model_dict', 'optimizer_dict'])
