# %%
# %run func_defs.ipynb

# %run NN_defs.ipynb

import time, os, random
seed = 42

start_new_nn = 1
nz = 80 ;
Lz=10 ; tf = 2; 
k1=1.0; k2= 2.0 
lr = .01
wd = .0001
epochs = 10000000
betas = (0.995, 0.999)
tol = 5e-08
#nodes = 32
out_file= f'./model/2layer_nz{nz}_tf{tf}.pt'
dat_file = f'./data/2layer_k1{k1}_k2{k2}_nz{nz}.pt'
d_in= 4

# %%
# set a dictionary of parameters
params_def = {'d_in':4, 'd_out':1, 'layers':4, 'nodes':64,
    'tol':0.5e-6, 'epochs':1000000, 'seg_size':1000, 'epoch_0':0,
    'lr':0.005, 'eps':1e-10, 'betas':(0.995, 0.999), 'wd':1e-4,
    'L':10, 'N':100000, 'N_test':100000,
    'start_new_nn':1, 'dat_file':f'./data/tm_in.pt',
    'out_file':f'./data/tm_out.pt'} 
for name in params_def: # using existing unless not existent
    if name not in globals():
        globals()[name] = params_def[name]

sec_main = """
# Load the training data
trn_dat = torch.load(dat_file, weights_only=True)

device = torch.device('cuda')

stau = trn_dat['stau']
W = trn_dat['W']
kratio = trn_dat['kratio']
z_disv = trn_dat['zdis']


train = torch.stack([stau[:,0],stau[:,1], kratio, z_disv], dim=-1)

xtrain = train.to(torch.float64)
ytrain = W.to(torch.float64)

print(train.shape)
print(W.shape)
if start_new_nn == 1:
    model, optimizer = build_nn() # build a new model
    model = model.to(device)
    del start_new_nn
else:
    model, optimizer = rebuild_nn() # rebuild the model from saved data
    model = model.to(device)
    for state in optimizer.state.values():
        for k, v in state.items():
            if isinstance(v, torch.Tensor):
                state[k] = v.to(device)
print(f'neural network model is on {next(model.parameters()).device}')
print_params() # print parameters
#
trained_model = train_nn() # train the model
for key in trained_model: # unpack trained_model
    globals()[key] = trained_model[key]
# test_result = test_and_plotting() # test the model and plot results
# for key in test_result: # unpack test_result
   # globals()[key] = test_result[key]
#
print_params()
[print(msg) for msg in msg_train]
# [print(msg) for msg in msg_test
save_model_vars() # save the model and variables in a dictionary
"""

# %%
# run the code unless func_def_only ==1

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

exec(sec_main)
# Out:
# torch.Size([6561, 4])
# torch.Size([6561, 1])
# neural network model is on cuda:0
# Structure of neural network:  Net(
#   (layers): ModuleList(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1-3): 3 x Linear(in_features=64, out_features=64, bias=True)
#   )
#   (out): Linear(in_features=64, out_features=1, bias=True)
# )
# Optimizer:   AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.995, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-10
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 0.0001
# )
# parameters: d_in = 4, d_out = 1, layers = 4, nodes = 64
#     tol = 5.0000e-08, epochs = 10000000, seg_size = 1000, epoch_0 = 0
#     N_train = 100000, N_test = 100000
#     output file: ./model/2layer_nz80_tf2.pt
#
# i = 0, loss = 9.4701e-02 loss_curr_min = 9.4701e-02
# Elapsed time = 0.06s,  CA time = Fri May 15 17:16:55 2026
# i = 1000, loss = 2.0463e-02 loss_curr_min = 2.0432e-02
# Elapsed time = 1.45s,  CA time = Fri May 15 17:16:56 2026
# i = 2000, loss = 3.0335e-04 loss_curr_min = 1.1488e-04
# Elapsed time = 2.74s,  CA time = Fri May 15 17:16:57 2026
# i = 3000, loss = 9.0998e-06 loss_curr_min = 8.7999e-06
# Elapsed time = 4.06s,  CA time = Fri May 15 17:16:59 2026
# i = 4000, loss = 3.5735e-06 loss_curr_min = 3.5735e-06
# Elapsed time = 5.38s,  CA time = Fri May 15 17:17:00 2026
# i = 5000, loss = 2.4714e-06 loss_curr_min = 2.4714e-06
# Elapsed time = 6.71s,  CA time = Fri May 15 17:17:01 2026
# i = 6000, loss = 2.1618e-06 loss_curr_min = 1.9926e-06
# Elapsed time = 7.99s,  CA time = Fri May 15 17:17:03 2026
# i = 7000, loss = 1.6620e-06 loss_curr_min = 1.6587e-06
# Elapsed time = 9.30s,  CA time = Fri May 15 17:17:04 2026
# i = 8000, loss = 1.4991e-06 loss_curr_min = 1.4584e-06
# Elapsed time = 10.61s,  CA time = Fri May 15 17:17:05 2026
# i = 9000, loss = 1.4318e-06 loss_curr_min = 1.3403e-06
# Elapsed time = 11.90s,  CA time = Fri May 15 17:17:07 2026
# i = 10000, loss = 1.3354e-06 loss_curr_min = 1.2396e-06
# Elapsed time = 13.20s,  CA time = Fri May 15 17:17:08 2026
# i = 11000, loss = 1.2756e-06 loss_curr_min = 1.1446e-06
# Elapsed time = 14.48s,  CA time = Fri May 15 17:17:09 2026
# i = 12000, loss = 1.0900e-06 loss_curr_min = 1.0560e-06
# Elapsed time = 15.77s,  CA time = Fri May 15 17:17:10 2026
# i = 13000, loss = 1.0638e-06 loss_curr_min = 9.7865e-07
# Elapsed time = 17.05s,  CA time = Fri May 15 17:17:12 2026
# i = 14000, loss = 1.0736e-06 loss_curr_min = 9.1395e-07
# Elapsed time = 18.37s,  CA time = Fri May 15 17:17:13 2026
# i = 15000, loss = 9.0701e-07 loss_curr_min = 8.6028e-07
# Elapsed time = 19.68s,  CA time = Fri May 15 17:17:14 2026
# i = 16000, loss = 8.1591e-07 loss_curr_min = 8.1591e-07
# Elapsed time = 20.99s,  CA time = Fri May 15 17:17:16 2026
# i = 17000, loss = 8.8975e-07 loss_curr_min = 7.8104e-07
# Elapsed time = 22.30s,  CA time = Fri May 15 17:17:17 2026
# i = 18000, loss = 9.1090e-07 loss_curr_min = 7.5263e-07
# Elapsed time = 23.60s,  CA time = Fri May 15 17:17:18 2026
# i = 19000, loss = 8.3321e-07 loss_curr_min = 7.2882e-07
# Elapsed time = 24.91s,  CA time = Fri May 15 17:17:20 2026
# i = 20000, loss = 7.2964e-07 loss_curr_min = 7.0857e-07
# Elapsed time = 26.23s,  CA time = Fri May 15 17:17:21 2026
# i = 21000, loss = 7.8809e-07 loss_curr_min = 6.8950e-07
# Elapsed time = 27.52s,  CA time = Fri May 15 17:17:22 2026
# i = 22000, loss = 8.2276e-07 loss_curr_min = 6.7132e-07
# Elapsed time = 28.83s,  CA time = Fri May 15 17:17:24 2026
# i = 23000, loss = 8.3535e-07 loss_curr_min = 6.5374e-07
# Elapsed time = 30.15s,  CA time = Fri May 15 17:17:25 2026
# i = 24000, loss = 8.0635e-07 loss_curr_min = 6.3723e-07
# Elapsed time = 31.45s,  CA time = Fri May 15 17:17:26 2026
# i = 25000, loss = 8.1652e-07 loss_curr_min = 6.2079e-07
# Elapsed time = 32.76s,  CA time = Fri May 15 17:17:27 2026
# i = 26000, loss = 6.1237e-07 loss_curr_min = 6.0534e-07
# Elapsed time = 34.04s,  CA time = Fri May 15 17:17:29 2026
# i = 27000, loss = 7.8493e-07 loss_curr_min = 5.8909e-07
# Elapsed time = 35.34s,  CA time = Fri May 15 17:17:30 2026
# i = 28000, loss = 5.8989e-07 loss_curr_min = 5.7269e-07
# Elapsed time = 36.65s,  CA time = Fri May 15 17:17:31 2026
# i = 29000, loss = 6.1179e-07 loss_curr_min = 5.5965e-07
# Elapsed time = 37.94s,  CA time = Fri May 15 17:17:33 2026
# i = 30000, loss = 7.0935e-07 loss_curr_min = 5.4682e-07
# Elapsed time = 39.25s,  CA time = Fri May 15 17:17:34 2026
# i = 31000, loss = 7.2529e-07 loss_curr_min = 5.3365e-07
# Elapsed time = 40.59s,  CA time = Fri May 15 17:17:35 2026
# i = 32000, loss = 6.9807e-07 loss_curr_min = 5.2289e-07
# Elapsed time = 41.92s,  CA time = Fri May 15 17:17:37 2026
# i = 33000, loss = 6.8340e-07 loss_curr_min = 5.0891e-07
# Elapsed time = 43.23s,  CA time = Fri May 15 17:17:38 2026
# i = 34000, loss = 5.8741e-07 loss_curr_min = 4.8671e-07
# Elapsed time = 44.51s,  CA time = Fri May 15 17:17:39 2026
# i = 35000, loss = 4.6476e-07 loss_curr_min = 4.6476e-07
# Elapsed time = 45.80s,  CA time = Fri May 15 17:17:40 2026
# i = 36000, loss = 5.2212e-07 loss_curr_min = 4.4011e-07
# Elapsed time = 47.10s,  CA time = Fri May 15 17:17:42 2026
# i = 37000, loss = 4.3603e-07 loss_curr_min = 4.0562e-07
# Elapsed time = 48.39s,  CA time = Fri May 15 17:17:43 2026
# i = 38000, loss = 5.7426e-07 loss_curr_min = 3.8056e-07
# Elapsed time = 49.70s,  CA time = Fri May 15 17:17:44 2026
# i = 39000, loss = 4.2429e-07 loss_curr_min = 3.7163e-07
# Elapsed time = 51.03s,  CA time = Fri May 15 17:17:46 2026
# i = 40000, loss = 3.7324e-07 loss_curr_min = 3.6713e-07
# Elapsed time = 52.33s,  CA time = Fri May 15 17:17:47 2026
# i = 41000, loss = 4.4367e-07 loss_curr_min = 3.6302e-07
# Elapsed time = 53.63s,  CA time = Fri May 15 17:17:48 2026
# i = 42000, loss = 5.0478e-07 loss_curr_min = 3.5927e-07
# Elapsed time = 54.92s,  CA time = Fri May 15 17:17:50 2026
# i = 43000, loss = 5.3775e-07 loss_curr_min = 3.5551e-07
# Elapsed time = 56.23s,  CA time = Fri May 15 17:17:51 2026
# i = 44000, loss = 5.4085e-07 loss_curr_min = 3.5166e-07
# Elapsed time = 57.53s,  CA time = Fri May 15 17:17:52 2026
# i = 45000, loss = 5.0027e-07 loss_curr_min = 3.4792e-07
# Elapsed time = 58.83s,  CA time = Fri May 15 17:17:54 2026
# i = 46000, loss = 4.0424e-07 loss_curr_min = 3.4384e-07
# Elapsed time = 60.14s,  CA time = Fri May 15 17:17:55 2026
# i = 47000, loss = 3.5558e-07 loss_curr_min = 3.3986e-07
# Elapsed time = 61.46s,  CA time = Fri May 15 17:17:56 2026
# i = 48000, loss = 3.3857e-07 loss_curr_min = 3.3596e-07
# Elapsed time = 62.77s,  CA time = Fri May 15 17:17:57 2026
# i = 49000, loss = 3.3153e-07 loss_curr_min = 3.3153e-07
# Elapsed time = 64.08s,  CA time = Fri May 15 17:17:59 2026
# i = 50000, loss = 3.3262e-07 loss_curr_min = 3.2741e-07
# Elapsed time = 65.39s,  CA time = Fri May 15 17:18:00 2026
# i = 51000, loss = 3.5599e-07 loss_curr_min = 3.2294e-07
# Elapsed time = 66.69s,  CA time = Fri May 15 17:18:01 2026
# i = 52000, loss = 4.3592e-07 loss_curr_min = 3.1835e-07
# Elapsed time = 67.99s,  CA time = Fri May 15 17:18:03 2026
# i = 53000, loss = 4.9897e-07 loss_curr_min = 3.1376e-07
# Elapsed time = 69.32s,  CA time = Fri May 15 17:18:04 2026
# i = 54000, loss = 4.3182e-07 loss_curr_min = 3.0898e-07
# Elapsed time = 70.66s,  CA time = Fri May 15 17:18:05 2026
# i = 55000, loss = 3.1784e-07 loss_curr_min = 3.0431e-07
# Elapsed time = 71.98s,  CA time = Fri May 15 17:18:07 2026
# i = 56000, loss = 3.7080e-07 loss_curr_min = 2.9977e-07
# Elapsed time = 73.28s,  CA time = Fri May 15 17:18:08 2026
# i = 57000, loss = 2.9521e-07 loss_curr_min = 2.9521e-07
# Elapsed time = 74.60s,  CA time = Fri May 15 17:18:09 2026
# i = 58000, loss = 3.5604e-07 loss_curr_min = 2.9055e-07
# Elapsed time = 75.89s,  CA time = Fri May 15 17:18:11 2026
# i = 59000, loss = 4.1928e-07 loss_curr_min = 2.8616e-07
# Elapsed time = 77.19s,  CA time = Fri May 15 17:18:12 2026
# i = 60000, loss = 4.5061e-07 loss_curr_min = 2.8182e-07
# Elapsed time = 78.51s,  CA time = Fri May 15 17:18:13 2026
# i = 61000, loss = 3.6723e-07 loss_curr_min = 2.7768e-07
# Elapsed time = 79.83s,  CA time = Fri May 15 17:18:15 2026
# i = 62000, loss = 3.7640e-07 loss_curr_min = 2.7293e-07
# Elapsed time = 81.11s,  CA time = Fri May 15 17:18:16 2026
# i = 63000, loss = 3.9377e-07 loss_curr_min = 2.6840e-07
# Elapsed time = 82.40s,  CA time = Fri May 15 17:18:17 2026
# i = 64000, loss = 4.3691e-07 loss_curr_min = 2.6366e-07
# Elapsed time = 83.67s,  CA time = Fri May 15 17:18:18 2026
# i = 65000, loss = 2.7536e-07 loss_curr_min = 2.5922e-07
# Elapsed time = 84.95s,  CA time = Fri May 15 17:18:20 2026
# i = 66000, loss = 3.5852e-07 loss_curr_min = 2.5438e-07
# Elapsed time = 86.23s,  CA time = Fri May 15 17:18:21 2026
# i = 67000, loss = 3.8472e-07 loss_curr_min = 2.4942e-07
# Elapsed time = 87.52s,  CA time = Fri May 15 17:18:22 2026
# i = 68000, loss = 3.9901e-07 loss_curr_min = 2.4516e-07
# Elapsed time = 88.80s,  CA time = Fri May 15 17:18:23 2026
# i = 69000, loss = 3.2370e-07 loss_curr_min = 2.3956e-07
# Elapsed time = 90.12s,  CA time = Fri May 15 17:18:25 2026
# i = 70000, loss = 2.9175e-07 loss_curr_min = 2.3200e-07
# Elapsed time = 91.40s,  CA time = Fri May 15 17:18:26 2026
# i = 71000, loss = 3.0505e-07 loss_curr_min = 2.2855e-07
# Elapsed time = 92.69s,  CA time = Fri May 15 17:18:27 2026
# i = 72000, loss = 3.5270e-07 loss_curr_min = 2.1871e-07
# Elapsed time = 93.96s,  CA time = Fri May 15 17:18:29 2026
# i = 73000, loss = 3.5340e-07 loss_curr_min = 2.1185e-07
# Elapsed time = 95.24s,  CA time = Fri May 15 17:18:30 2026
# i = 74000, loss = 2.5706e-07 loss_curr_min = 2.0385e-07
# Elapsed time = 96.53s,  CA time = Fri May 15 17:18:31 2026
# i = 75000, loss = 1.9684e-07 loss_curr_min = 1.9684e-07
# Elapsed time = 97.81s,  CA time = Fri May 15 17:18:32 2026
# i = 76000, loss = 2.2309e-07 loss_curr_min = 1.9249e-07
# Elapsed time = 99.10s,  CA time = Fri May 15 17:18:34 2026
# i = 77000, loss = 2.5132e-07 loss_curr_min = 1.8589e-07
# Elapsed time = 100.41s,  CA time = Fri May 15 17:18:35 2026
# i = 78000, loss = 2.3304e-07 loss_curr_min = 1.7837e-07
# Elapsed time = 101.70s,  CA time = Fri May 15 17:18:36 2026
# i = 79000, loss = 1.7955e-07 loss_curr_min = 1.7377e-07
# Elapsed time = 103.00s,  CA time = Fri May 15 17:18:38 2026
# i = 80000, loss = 2.0682e-07 loss_curr_min = 1.6946e-07
# Elapsed time = 104.28s,  CA time = Fri May 15 17:18:39 2026
# i = 81000, loss = 3.0489e-07 loss_curr_min = 1.6437e-07
# Elapsed time = 105.57s,  CA time = Fri May 15 17:18:40 2026
# i = 82000, loss = 1.6405e-07 loss_curr_min = 1.6064e-07
# Elapsed time = 106.86s,  CA time = Fri May 15 17:18:42 2026
# i = 83000, loss = 2.9412e-07 loss_curr_min = 1.5628e-07
# Elapsed time = 108.16s,  CA time = Fri May 15 17:18:43 2026
# i = 84000, loss = 1.5380e-07 loss_curr_min = 1.5097e-07
# Elapsed time = 109.46s,  CA time = Fri May 15 17:18:44 2026
# i = 85000, loss = 2.5364e-07 loss_curr_min = 1.4607e-07
# Elapsed time = 110.77s,  CA time = Fri May 15 17:18:45 2026
# i = 86000, loss = 2.0816e-07 loss_curr_min = 1.4185e-07
# Elapsed time = 112.04s,  CA time = Fri May 15 17:18:47 2026
# i = 87000, loss = 1.8079e-07 loss_curr_min = 1.3843e-07
# Elapsed time = 113.32s,  CA time = Fri May 15 17:18:48 2026
# i = 88000, loss = 2.4948e-07 loss_curr_min = 1.3612e-07
# Elapsed time = 114.58s,  CA time = Fri May 15 17:18:49 2026
# i = 89000, loss = 1.4187e-07 loss_curr_min = 1.3379e-07
# Elapsed time = 115.85s,  CA time = Fri May 15 17:18:51 2026
# i = 90000, loss = 2.6444e-07 loss_curr_min = 1.3207e-07
# Elapsed time = 117.12s,  CA time = Fri May 15 17:18:52 2026
# i = 91000, loss = 1.3055e-07 loss_curr_min = 1.3048e-07
# Elapsed time = 118.40s,  CA time = Fri May 15 17:18:53 2026
# i = 92000, loss = 2.6115e-07 loss_curr_min = 1.2897e-07
# Elapsed time = 119.71s,  CA time = Fri May 15 17:18:54 2026
# i = 93000, loss = 1.2818e-07 loss_curr_min = 1.2752e-07
# Elapsed time = 121.00s,  CA time = Fri May 15 17:18:56 2026
# i = 94000, loss = 2.5318e-07 loss_curr_min = 1.2612e-07
# Elapsed time = 122.29s,  CA time = Fri May 15 17:18:57 2026
# i = 95000, loss = 1.3763e-07 loss_curr_min = 1.2480e-07
# Elapsed time = 123.58s,  CA time = Fri May 15 17:18:58 2026
# i = 96000, loss = 2.2266e-07 loss_curr_min = 1.2367e-07
# Elapsed time = 124.87s,  CA time = Fri May 15 17:19:00 2026
# i = 97000, loss = 1.7818e-07 loss_curr_min = 1.2261e-07
# Elapsed time = 126.17s,  CA time = Fri May 15 17:19:01 2026
# i = 98000, loss = 1.6295e-07 loss_curr_min = 1.2139e-07
# Elapsed time = 127.45s,  CA time = Fri May 15 17:19:02 2026
# i = 99000, loss = 2.3456e-07 loss_curr_min = 1.2028e-07
# Elapsed time = 128.76s,  CA time = Fri May 15 17:19:03 2026
# i = 100000, loss = 1.1935e-07 loss_curr_min = 1.1925e-07
# Elapsed time = 130.05s,  CA time = Fri May 15 17:19:05 2026
# i = 101000, loss = 2.3225e-07 loss_curr_min = 1.1824e-07
# Elapsed time = 131.34s,  CA time = Fri May 15 17:19:06 2026
# i = 102000, loss = 1.6325e-07 loss_curr_min = 1.1738e-07
# Elapsed time = 132.63s,  CA time = Fri May 15 17:19:07 2026
# i = 103000, loss = 1.4896e-07 loss_curr_min = 1.1647e-07
# Elapsed time = 133.92s,  CA time = Fri May 15 17:19:09 2026
# i = 104000, loss = 2.3644e-07 loss_curr_min = 1.1546e-07
# Elapsed time = 135.21s,  CA time = Fri May 15 17:19:10 2026
# i = 105000, loss = 1.2448e-07 loss_curr_min = 1.1445e-07
# Elapsed time = 136.48s,  CA time = Fri May 15 17:19:11 2026
# i = 106000, loss = 1.7863e-07 loss_curr_min = 1.1370e-07
# Elapsed time = 137.73s,  CA time = Fri May 15 17:19:12 2026
# i = 107000, loss = 2.1914e-07 loss_curr_min = 1.1269e-07
# Elapsed time = 138.99s,  CA time = Fri May 15 17:19:14 2026
# i = 108000, loss = 1.1452e-07 loss_curr_min = 1.1192e-07
# Elapsed time = 140.29s,  CA time = Fri May 15 17:19:15 2026
# i = 109000, loss = 1.8249e-07 loss_curr_min = 1.1116e-07
# Elapsed time = 141.59s,  CA time = Fri May 15 17:19:16 2026
# i = 110000, loss = 2.1514e-07 loss_curr_min = 1.1013e-07
# Elapsed time = 142.86s,  CA time = Fri May 15 17:19:18 2026
# i = 111000, loss = 1.1534e-07 loss_curr_min = 1.0936e-07
# Elapsed time = 144.14s,  CA time = Fri May 15 17:19:19 2026
# i = 112000, loss = 1.6136e-07 loss_curr_min = 1.0858e-07
# Elapsed time = 145.41s,  CA time = Fri May 15 17:19:20 2026
# i = 113000, loss = 2.2087e-07 loss_curr_min = 1.0780e-07
# Elapsed time = 146.67s,  CA time = Fri May 15 17:19:21 2026
# i = 114000, loss = 1.3446e-07 loss_curr_min = 1.0701e-07
# Elapsed time = 147.94s,  CA time = Fri May 15 17:19:23 2026
# i = 115000, loss = 1.2316e-07 loss_curr_min = 1.0622e-07
# Elapsed time = 149.24s,  CA time = Fri May 15 17:19:24 2026
# i = 116000, loss = 2.0899e-07 loss_curr_min = 1.0543e-07
# Elapsed time = 150.55s,  CA time = Fri May 15 17:19:25 2026
# i = 117000, loss = 1.8187e-07 loss_curr_min = 1.0485e-07
# Elapsed time = 151.84s,  CA time = Fri May 15 17:19:27 2026
# i = 118000, loss = 1.0546e-07 loss_curr_min = 1.0411e-07
# Elapsed time = 153.15s,  CA time = Fri May 15 17:19:28 2026
# i = 119000, loss = 1.5148e-07 loss_curr_min = 1.0331e-07
# Elapsed time = 154.46s,  CA time = Fri May 15 17:19:29 2026
# i = 120000, loss = 2.1121e-07 loss_curr_min = 1.0255e-07
# Elapsed time = 155.75s,  CA time = Fri May 15 17:19:30 2026
# i = 121000, loss = 1.5220e-07 loss_curr_min = 1.0201e-07
# Elapsed time = 157.04s,  CA time = Fri May 15 17:19:32 2026
# i = 122000, loss = 1.0177e-07 loss_curr_min = 1.0124e-07
# Elapsed time = 158.33s,  CA time = Fri May 15 17:19:33 2026
# i = 123000, loss = 1.6486e-07 loss_curr_min = 1.0073e-07
# Elapsed time = 159.63s,  CA time = Fri May 15 17:19:34 2026
# i = 124000, loss = 2.0366e-07 loss_curr_min = 9.9985e-08
# Elapsed time = 160.94s,  CA time = Fri May 15 17:19:36 2026
# i = 125000, loss = 1.3349e-07 loss_curr_min = 9.9253e-08
# Elapsed time = 162.27s,  CA time = Fri May 15 17:19:37 2026
# i = 126000, loss = 1.0371e-07 loss_curr_min = 9.8771e-08
# Elapsed time = 163.60s,  CA time = Fri May 15 17:19:38 2026
# i = 127000, loss = 1.8366e-07 loss_curr_min = 9.7994e-08
# Elapsed time = 164.88s,  CA time = Fri May 15 17:19:40 2026
# i = 128000, loss = 9.6154e-08 loss_curr_min = 9.6084e-08
# Elapsed time = 166.15s,  CA time = Fri May 15 17:19:41 2026
# i = 129000, loss = 1.5311e-07 loss_curr_min = 9.5106e-08
# Elapsed time = 167.42s,  CA time = Fri May 15 17:19:42 2026
# i = 130000, loss = 1.8940e-07 loss_curr_min = 9.3805e-08
# Elapsed time = 168.71s,  CA time = Fri May 15 17:19:43 2026
# i = 131000, loss = 1.8838e-07 loss_curr_min = 9.3054e-08
# Elapsed time = 170.00s,  CA time = Fri May 15 17:19:45 2026
# i = 132000, loss = 1.6141e-07 loss_curr_min = 9.1982e-08
# Elapsed time = 171.28s,  CA time = Fri May 15 17:19:46 2026
# i = 133000, loss = 1.2394e-07 loss_curr_min = 9.0810e-08
# Elapsed time = 172.57s,  CA time = Fri May 15 17:19:47 2026
# i = 134000, loss = 9.5354e-08 loss_curr_min = 9.0106e-08
# Elapsed time = 173.85s,  CA time = Fri May 15 17:19:49 2026
# i = 135000, loss = 9.1396e-08 loss_curr_min = 8.9436e-08
# Elapsed time = 175.13s,  CA time = Fri May 15 17:19:50 2026
# i = 136000, loss = 1.1520e-07 loss_curr_min = 8.8706e-08
# Elapsed time = 176.42s,  CA time = Fri May 15 17:19:51 2026
# i = 137000, loss = 1.5281e-07 loss_curr_min = 8.7594e-08
# Elapsed time = 177.70s,  CA time = Fri May 15 17:19:52 2026
# i = 138000, loss = 1.7780e-07 loss_curr_min = 8.7032e-08
# Elapsed time = 178.99s,  CA time = Fri May 15 17:19:54 2026
# i = 139000, loss = 1.6765e-07 loss_curr_min = 8.5973e-08
# Elapsed time = 180.28s,  CA time = Fri May 15 17:19:55 2026
# i = 140000, loss = 1.2588e-07 loss_curr_min = 8.5471e-08
# Elapsed time = 181.57s,  CA time = Fri May 15 17:19:56 2026
# i = 141000, loss = 8.8260e-08 loss_curr_min = 8.4514e-08
# Elapsed time = 182.90s,  CA time = Fri May 15 17:19:58 2026
# i = 142000, loss = 9.4358e-08 loss_curr_min = 8.3631e-08
# Elapsed time = 184.23s,  CA time = Fri May 15 17:19:59 2026
# i = 143000, loss = 1.4463e-07 loss_curr_min = 8.2835e-08
# Elapsed time = 185.57s,  CA time = Fri May 15 17:20:00 2026
# i = 144000, loss = 1.6847e-07 loss_curr_min = 8.2117e-08
# Elapsed time = 186.90s,  CA time = Fri May 15 17:20:02 2026
# i = 145000, loss = 1.0172e-07 loss_curr_min = 8.1157e-08
# Elapsed time = 188.24s,  CA time = Fri May 15 17:20:03 2026
# i = 146000, loss = 1.0832e-07 loss_curr_min = 8.0029e-08
# Elapsed time = 189.55s,  CA time = Fri May 15 17:20:04 2026
# i = 147000, loss = 1.5481e-07 loss_curr_min = 7.8765e-08
# Elapsed time = 190.84s,  CA time = Fri May 15 17:20:06 2026
# i = 148000, loss = 7.9074e-08 loss_curr_min = 7.7506e-08
# Elapsed time = 192.13s,  CA time = Fri May 15 17:20:07 2026
# i = 149000, loss = 1.4205e-07 loss_curr_min = 7.6423e-08
# Elapsed time = 193.41s,  CA time = Fri May 15 17:20:08 2026
# i = 150000, loss = 1.5794e-07 loss_curr_min = 7.5921e-08
# Elapsed time = 194.69s,  CA time = Fri May 15 17:20:09 2026
# i = 151000, loss = 1.5694e-07 loss_curr_min = 7.5789e-08
# Elapsed time = 195.97s,  CA time = Fri May 15 17:20:11 2026
# i = 152000, loss = 1.5419e-07 loss_curr_min = 7.5789e-08
# Elapsed time = 197.26s,  CA time = Fri May 15 17:20:12 2026
# i = 153000, loss = 1.5170e-07 loss_curr_min = 7.4780e-08
# Elapsed time = 198.54s,  CA time = Fri May 15 17:20:13 2026
# i = 154000, loss = 1.5067e-07 loss_curr_min = 7.4427e-08
# Elapsed time = 199.83s,  CA time = Fri May 15 17:20:15 2026
# i = 155000, loss = 1.5100e-07 loss_curr_min = 7.4427e-08
# Elapsed time = 201.12s,  CA time = Fri May 15 17:20:16 2026
# i = 156000, loss = 1.5138e-07 loss_curr_min = 7.2717e-08
# Elapsed time = 202.41s,  CA time = Fri May 15 17:20:17 2026
# i = 157000, loss = 1.5001e-07 loss_curr_min = 7.2366e-08
# Elapsed time = 203.69s,  CA time = Fri May 15 17:20:18 2026
# i = 158000, loss = 1.4505e-07 loss_curr_min = 7.2204e-08
# Elapsed time = 204.96s,  CA time = Fri May 15 17:20:20 2026
# i = 159000, loss = 1.3496e-07 loss_curr_min = 7.1676e-08
# Elapsed time = 206.25s,  CA time = Fri May 15 17:20:21 2026
# i = 160000, loss = 1.1933e-07 loss_curr_min = 7.1196e-08
# Elapsed time = 207.54s,  CA time = Fri May 15 17:20:22 2026
# i = 161000, loss = 9.9964e-08 loss_curr_min = 7.0998e-08
# Elapsed time = 208.82s,  CA time = Fri May 15 17:20:24 2026
# i = 162000, loss = 8.1566e-08 loss_curr_min = 7.0815e-08
# Elapsed time = 210.11s,  CA time = Fri May 15 17:20:25 2026
# i = 163000, loss = 7.0907e-08 loss_curr_min = 7.0490e-08
# Elapsed time = 211.45s,  CA time = Fri May 15 17:20:26 2026
# i = 164000, loss = 7.3948e-08 loss_curr_min = 7.0203e-08
# Elapsed time = 212.79s,  CA time = Fri May 15 17:20:27 2026
# Structure of neural network:  Net(
#   (layers): ModuleList(
#     (0): Linear(in_features=4, out_features=64, bias=True)
#     (1-3): 3 x Linear(in_features=64, out_features=64, bias=True)
#   )
#   (out): Linear(in_features=64, out_features=1, bias=True)
# )
# Optimizer:   AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.995, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-10
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 0.0001
# )
# parameters: d_in = 4, d_out = 1, layers = 4, nodes = 64
#     tol = 5.0000e-08, epochs = 10000000, seg_size = 1000, epoch_0 = 0
#     N_train = 100000, N_test = 100000
#     output file: ./model/2layer_nz80_tf2.pt
#
# Training info: tol_actual = 5.0000e-08, epochs_actual = 164169
#     loss_train(MSE) = 6.9995e-08
#     Elapsed time = 213.02s,  CA time = Fri May 15 17:20:28 2026
# dict_keys(['seed', 'nz', 'Lz', 'tf', 'k1', 'k2', 'lr', 'wd', 'epochs', 'tol', 'd_in', 'd_out', 'layers', 'nodes', 'seg_size', 'epoch_0', 'eps', 'L', 'N', 'N_test', 'model_dict', 'optimizer_dict'])
