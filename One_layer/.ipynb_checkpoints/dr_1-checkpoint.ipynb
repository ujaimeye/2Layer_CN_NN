# %%
# %reset -f
# Install papermill
# pip install papermill

import papermill as pm

# List your notebooks in the exact order you want them to run
# notebooks = ['mb2_cs1_R3A4.ipynb', 'mb2_cs1_R3B4.ipynb',
#              'mb2_cs1_R1.ipynb',
#              'mb2_cs1_R3A3.ipynb', 'mb2_cs1_R3B3.ipynb',
#              'mb2_cs1_R3A2.ipynb', 'mb2_cs1_R3B2.ipynb',
#              'mb2_cs1_R2.ipynb',
#              'mb2_cs1_R3A.ipynb', 'mb2_cs1_R3B.ipynb']

notebooks = ['TM_n2_DCB.ipynb', 'TM_n2_CB.ipynb', 'TM_n2_BC.ipynb']

for nb in notebooks:
    print(f"--- Starting execution of {nb} ---")
    pm.execute_notebook(
        input_path=nb,
        output_path=nb,
        # parameters=dict(alpha=0.1, ratio=5),
        log_output=True,  # This mirrors output to your current screen
        progress_bar=True # Optional: shows a live progress bar
    )

print(f'--- All notebooks are completed ---')
